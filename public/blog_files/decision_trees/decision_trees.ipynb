# %%
import pandas as pd

# %% [markdown]
# <h1>Building a Decision Tree</h1>

# %%
# Load in our data
df = pd.DataFrame({
    'Patient ID': [1, 2, 3, 4, 5, 6],
    "Chest Pain": [True, True, False, False, True, False],
    'Male': [True, True, False, True, False, True],
    'Exercises': [True, False, False, True, True, True],
    'Heart Attack': [True, True, True, False, True, False]  
})

# %%
# Import and load in our decision tree model from sklearn
from sklearn.tree import DecisionTreeClassifier, plot_tree
dtc = DecisionTreeClassifier(criterion='gini')

# Separate our data into X and y
X = df.drop(columns=['Patient ID', 'Heart Attack'])
y = df['Heart Attack']

# Plug into our Decision Tree Classifier
dtc.fit(X, y)

# Plot our tree to see what it looks like.
plot_tree(dtc, feature_names=['Chest Pain', 'Male', 'Exercises'])
# Out:
# [Text(0.6, 0.8333333333333334, 'Chest Pain <= 0.5\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.4, 0.5, 'Male <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.2, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6, 0.16666666666666666, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.8, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]')]

# %% [markdown]
# As we can see, we end up with the exact same splits as our hand-make tree!
